# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df1_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-cpu-dispatch/cart.csv')
df2_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-fileIO-payment/cart.csv')
df3_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user/cart.csv')
df4_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user-2/cart.csv')
df5_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-load-1500/cart.csv')
df6_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user/cart.csv')
df7_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user-2/cart.csv')
df8_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/memory-leak-cart/cart.csv')
df9_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user/cart.csv')
df10_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user-2/cart.csv')
df11_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user/cart.csv')
df12_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user-2/cart.csv')
df13_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/rt-delay-catalogue/cart.csv')
df14_cart = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/service-down-payment/cart.csv')

df1_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-cpu-dispatch_rt/cart.csv')
df2_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-fileIO-payment_rt/cart.csv')
df3_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user_rt/cart.csv')
# df4_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user-2_rt/cart.csv')
df5_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-load-1500_rt/cart.csv')
df6_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user_rt/cart.csv')
df7_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user-2_rt/cart.csv')
df8_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/memory-leak-cart_rt/cart.csv')
df9_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user_rt/cart.csv')
df10_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user-2_rt/cart.csv')
df11_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user_rt/cart.csv')
# df12_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user-2_rt/cart.csv')
df13_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/rt-delay-catalogue_rt/cart.csv')
# df14_cart_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/service-down-payment_rt/cart.csv')

# %%
# add a new column called anomaly_type

# high-cpu-dispatch' = 1
# 'high-fileIO-payment' = 2
# 'high-latency-user' = 3
# 'high-latency-user-2' = 4
# 'high-load-1500' = 5
# 'low-bandwidth-user' = 6
# 'low-bandwidth-user-2' = 7
# 'memory-leak-cart' = 8
# 'out-of-order-packets-user' = 9
# 'out-of-order-packets-user-2' = 10
# 'packetloss-user' = 11
# 'packetloss-user-2' = 12
# 'rt-delay-catalogue' = 13
# 'service-down-payment' = 14

df1_cart['anomaly_type'] = 1
df2_cart['anomaly_type'] = 2
df3_cart['anomaly_type'] = 3
df4_cart['anomaly_type'] = 4
df5_cart['anomaly_type'] = 5
df6_cart['anomaly_type'] = 6
df7_cart['anomaly_type'] = 7
df8_cart['anomaly_type'] = 8
df9_cart['anomaly_type'] = 9
df10_cart['anomaly_type'] = 10
df11_cart['anomaly_type'] = 11
df12_cart['anomaly_type'] = 12
df13_cart['anomaly_type'] = 13
df14_cart['anomaly_type'] = 14

# %%
# print the columns for each _rt csv

print(df1_cart_rt.columns)
print(df2_cart_rt.columns)
print(df3_cart_rt.columns)
print(df5_cart_rt.columns)
print(df6_cart_rt.columns)
print(df7_cart_rt.columns)
print(df8_cart_rt.columns)
print(df9_cart_rt.columns)
print(df10_cart_rt.columns)
print(df11_cart_rt.columns)
print(df13_cart_rt.columns)
# Out:
# Index(['timestamp', 'rt_payment_delete_cart_count',
#        'rt_payment_delete_cart_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_payment_delete_cart_count',
#        'rt_payment_delete_cart_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_payment_delete_cart_count',
#        'rt_payment_delete_cart_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_payment_delete_cart_count',
#        'rt_payment_delete_cart_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_payment_delete_cart_count',
#        'rt_payment_delete_cart_sum'],
#       dtype='object')
# Index(['Unnamed: 0', 'timestamp', 'rt_payment_delete_cart_count',
#        'rt_payment_delete_cart_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_payment_delete_cart_count',
#        'rt_payment_delete_cart_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_payment_delete_cart_count',
#        'rt_payment_delete_cart_sum'],
#       dtype='object')
# ...

# %%
# merge all the df#_cart dataframes to create df_cart dataframe

df_cart = pd.concat([df1_cart, df2_cart, df3_cart, df4_cart, df5_cart,
                      df6_cart, df7_cart, df8_cart, df9_cart, df10_cart,
                      df11_cart, df12_cart, df13_cart, df14_cart], ignore_index=True)

# %%
# Combined cart microservice
print(df_cart.shape)
# Out:
# (27782, 21)

# %%
# prompt: print the shapes of each dataframe

print("Cart CAdvisor")
print(df1_cart.shape)
print(df2_cart.shape)
print(df3_cart.shape)
print(df4_cart.shape)
print(df5_cart.shape)
print(df6_cart.shape)
print(df7_cart.shape)
print(df8_cart.shape)
print(df9_cart.shape)
print(df10_cart.shape)
print(df11_cart.shape)
print(df12_cart.shape)
print(df13_cart.shape)
print(df14_cart.shape)
print("\nCart Response Time")
print(df1_cart_rt.shape)
print(df2_cart_rt.shape)
print(df3_cart_rt.shape)
# print(df4_cart_rt.shape)
print(df5_cart_rt.shape)
print(df6_cart_rt.shape)
print(df7_cart_rt.shape)
print(df8_cart_rt.shape)
print(df9_cart_rt.shape)
print(df10_cart_rt.shape)
print(df11_cart_rt.shape)
# print(df12_cart_rt.shape)
print(df13_cart_rt.shape)
# print(df14_cart_rt.shape)
# Out:
# Cart CAdvisor
# (1255, 21)
# (1260, 21)
# (1260, 21)
# (4302, 21)
# (3054, 21)
# (1260, 21)
# (2365, 21)
# (1260, 21)
# (1260, 21)
# (2260, 21)
# (1260, 21)
# (4466, 21)
# (1260, 21)
# (1260, 21)
#
# Cart Response Time
# (1259, 3)
# (1260, 3)
# (1204, 3)
# (1080, 3)
# (1260, 3)
# (2393, 4)
# (1260, 3)
# (1260, 3)
# (2275, 4)
# (1014, 3)
# (1260, 3)

# %%
# CSV import for user dataframes from cadvisor
df1_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-cpu-dispatch/user.csv')
df2_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-fileIO-payment/user.csv')
df3_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user/user.csv')
df4_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user-2/user.csv')
df5_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-load-1500/user.csv')
df6_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user/user.csv')
df7_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user-2/user.csv')
df8_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/memory-leak-cart/user.csv')
df9_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user/user.csv')
df10_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user-2/user.csv')
df11_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user/user.csv')
df12_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user-2/user.csv')
df13_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/rt-delay-catalogue/user.csv')
df14_user = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/service-down-payment/user.csv')

# CSV import for user dataframes from response time
df1_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-cpu-dispatch_rt/user.csv')
df2_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-fileIO-payment_rt/user.csv')
df3_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user_rt/user.csv')
# df4_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user-2_rt/user.csv')
df5_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-load-1500_rt/user.csv')
df6_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user_rt/user.csv')
df7_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user-2_rt/user.csv')
df8_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/memory-leak-cart_rt/user.csv')
df9_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user_rt/user.csv')
df10_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user-2_rt/user.csv')
df11_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user_rt/user.csv')
# df12_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user-2_rt/user.csv')
df13_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/rt-delay-catalogue_rt/user.csv')
# df14_user_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/service-down-payment_rt/user.csv')

# %%
df1_user['anomaly_type'] = 1
df2_user['anomaly_type'] = 2
df3_user['anomaly_type'] = 3
df4_user['anomaly_type'] = 4
df5_user['anomaly_type'] = 5
df6_user['anomaly_type'] = 6
df7_user['anomaly_type'] = 7
df8_user['anomaly_type'] = 8
df9_user['anomaly_type'] = 9
df10_user['anomaly_type'] = 10
df11_user['anomaly_type'] = 11
df12_user['anomaly_type'] = 12
df13_user['anomaly_type'] = 13
df14_user['anomaly_type'] = 14

# %%
# prompt: print the shapes of dataframes above

print("User CAdvisor")
print(df1_user.shape)
print(df2_user.shape)
print(df3_user.shape)
print(df4_user.shape)
print(df5_user.shape)
print(df6_user.shape)
print(df7_user.shape)
print(df8_user.shape)
print(df9_user.shape)
print(df10_user.shape)
print(df11_user.shape)
print(df12_user.shape)
print(df13_user.shape)
print(df14_user.shape)
print("\nUser Response Time")
print(df1_user_rt.shape)
print(df2_user_rt.shape)
print(df3_user_rt.shape)
# print(df4_user_rt.shape)
print(df5_user_rt.shape)
print(df6_user_rt.shape)
print(df7_user_rt.shape)
print(df8_user_rt.shape)
print(df9_user_rt.shape)
print(df10_user_rt.shape)
print(df11_user_rt.shape)
# print(df12_user_rt.shape)
print(df13_user_rt.shape)
# print(df14_user_rt.shape)
# Out:
# User CAdvisor
# (1255, 21)
# (1260, 21)
# (1260, 21)
# (4040, 21)
# (3055, 21)
# (1260, 21)
# (2325, 21)
# (1260, 21)
# (1260, 21)
# (2217, 21)
# (1260, 21)
# (5738, 21)
# (1260, 21)
# (1260, 21)
#
# User Response Time
# (1259, 5)
# (1260, 5)
# (1204, 5)
# (1080, 5)
# (1260, 5)
# (2329, 6)
# (1260, 5)
# (1260, 5)
# (2208, 6)
# (1014, 5)
# (1260, 5)

# %%
# merge all the df#_user dataframes to create df_user dataframe

df_user = pd.concat([df1_user, df2_user, df3_user, df4_user, df5_user,
                      df6_user, df7_user, df8_user, df9_user, df10_user,
                      df11_user, df12_user, df13_user, df14_user], ignore_index=True)

# %%
# Merged user Dataframe
print(df_user.shape)
# Out:
# (28710, 21)

# %%
print(df1_user_rt.columns)
print(df2_user_rt.columns)
print(df3_user_rt.columns)
# print(df4_user_rt.columns)
print(df5_user_rt.columns)
print(df6_user_rt.columns)
print(df7_user_rt.columns)
print(df8_user_rt.columns)
print(df9_user_rt.columns)
print(df10_user_rt.columns)
print(df11_user_rt.columns)
# print(df12_user_rt.columns)
print(df13_user_rt.columns)
# print(df14_user_rt.columns)
# Out:
# Index(['timestamp', 'rt_payment_get_user_count', 'rt_payment_get_user_sum',
#        'rt_payment_post_user_count', 'rt_payment_post_user_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_payment_get_user_count', 'rt_payment_get_user_sum',
#        'rt_payment_post_user_count', 'rt_payment_post_user_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_payment_get_user_count', 'rt_payment_get_user_sum',
#        'rt_payment_post_user_count', 'rt_payment_post_user_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_payment_get_user_count', 'rt_payment_get_user_sum',
#        'rt_payment_post_user_count', 'rt_payment_post_user_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_payment_get_user_count', 'rt_payment_get_user_sum',
#        'rt_payment_post_user_count', 'rt_payment_post_user_sum'],
#       dtype='object')
# Index(['Unnamed: 0', 'timestamp', 'rt_payment_get_user_count',
#        'rt_payment_get_user_sum', 'rt_payment_post_user_count',
# ...

# %%
# CSV import for catalogue dataframes from cadvisor
df1_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-cpu-dispatch/catalogue.csv')
df2_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-fileIO-payment/catalogue.csv')
df3_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user/catalogue.csv')
df4_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user-2/catalogue.csv')
df5_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-load-1500/catalogue.csv')
df6_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user/catalogue.csv')
df7_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user-2/catalogue.csv')
df8_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/memory-leak-cart/catalogue.csv')
df9_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user/catalogue.csv')
df10_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user-2/catalogue.csv')
df11_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user/catalogue.csv')
df12_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user-2/catalogue.csv')
df13_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/rt-delay-catalogue/catalogue.csv')
df14_catalogue = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/service-down-payment/catalogue.csv')

# CSV import for catalogue dataframes from response time
df1_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-cpu-dispatch_rt/catalogue.csv')
df2_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-fileIO-payment_rt/catalogue.csv')
df3_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user_rt/catalogue.csv')
df4_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user-2_rt/catalogue.csv')
df5_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-load-1500_rt/catalogue.csv')
df6_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user_rt/catalogue.csv')
df7_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user-2_rt/catalogue.csv')
df8_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/memory-leak-cart_rt/catalogue.csv')
df9_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user_rt/catalogue.csv')
df10_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user-2_rt/catalogue.csv')
df11_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user_rt/catalogue.csv')
df12_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user-2_rt/catalogue.csv')
df13_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/rt-delay-catalogue_rt/catalogue.csv')
df14_catalogue_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/service-down-payment_rt/catalogue.csv')

# %%
df1_catalogue['anomaly_type'] = 1
df2_catalogue['anomaly_type'] = 2
df3_catalogue['anomaly_type'] = 3
df4_catalogue['anomaly_type'] = 4
df5_catalogue['anomaly_type'] = 5
df6_catalogue['anomaly_type'] = 6
df7_catalogue['anomaly_type'] = 7
df8_catalogue['anomaly_type'] = 8
df9_catalogue['anomaly_type'] = 9
df10_catalogue['anomaly_type'] = 10
df11_catalogue['anomaly_type'] = 11
df12_catalogue['anomaly_type'] = 12
df13_catalogue['anomaly_type'] = 13
df14_catalogue['anomaly_type'] = 14

# %%
# merge all the df#_catalogue dataframes to create df_catalogue dataframe

df_catalogue = pd.concat([df1_catalogue, df2_catalogue, df3_catalogue, df4_catalogue, df5_catalogue,
                      df6_catalogue, df7_catalogue, df8_catalogue, df9_catalogue, df10_catalogue,
                      df11_catalogue, df12_catalogue, df13_catalogue, df14_catalogue], ignore_index=True)

# %%
# Merged catalogue Dataframe
print(df_catalogue.shape)
# Out:
# (29103, 21)

# %%
print("Catalogue CAdvisor")
print(df1_catalogue.shape)
print(df2_catalogue.shape)
print(df3_catalogue.shape)
print(df4_catalogue.shape)
print(df5_catalogue.shape)
print(df6_catalogue.shape)
print(df7_catalogue.shape)
print(df8_catalogue.shape)
print(df9_catalogue.shape)
print(df10_catalogue.shape)
print(df11_catalogue.shape)
print(df12_catalogue.shape)
print(df13_catalogue.shape)
print(df14_catalogue.shape)
print("\nCatalogue Response Time")
print(df1_catalogue_rt.shape)
print(df2_catalogue_rt.shape)
print(df3_catalogue_rt.shape)
print(df4_catalogue_rt.shape)
print(df5_catalogue_rt.shape)
print(df6_catalogue_rt.shape)
print(df7_catalogue_rt.shape)
print(df8_catalogue_rt.shape)
print(df9_catalogue_rt.shape)
print(df10_catalogue_rt.shape)
print(df11_catalogue_rt.shape)
print(df12_catalogue_rt.shape)
print(df13_catalogue_rt.shape)
print(df14_catalogue_rt.shape)
# Out:
# Catalogue CAdvisor
# (1255, 21)
# (1260, 21)
# (1260, 21)
# (4305, 21)
# (3054, 21)
# (1260, 21)
# (2387, 21)
# (1260, 21)
# (1260, 21)
# (2283, 21)
# (1260, 21)
# (5739, 21)
# (1260, 21)
# (1260, 21)
#
# Catalogue Response Time
# (1255, 5)
# (1260, 5)
# (1260, 5)
# (4303, 6)
# (1080, 5)
# (1260, 5)
# (2422, 6)
# (1260, 5)
# (1260, 5)
# (2306, 6)
# (1260, 5)
# (5746, 6)
# (1260, 5)
# (1260, 5)

# %%
print(df1_catalogue_rt.columns)
print(df2_catalogue_rt.columns)
print(df3_catalogue_rt.columns)
print(df4_catalogue_rt.columns)
print(df5_catalogue_rt.columns)
print(df6_catalogue_rt.columns)
print(df7_catalogue_rt.columns)
print(df8_catalogue_rt.columns)
print(df9_catalogue_rt.columns)
print(df10_catalogue_rt.columns)
print(df11_catalogue_rt.columns)
print(df12_catalogue_rt.columns)
print(df13_catalogue_rt.columns)
print(df14_catalogue_rt.columns)
# Out:
# Index(['timestamp', 'rt_cart_get_catalogue_count', 'rt_cart_get_catalogue_sum',
#        'rt_ratings_get_catalogue_count', 'rt_ratings_get_catalogue_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_cart_get_catalogue_count', 'rt_cart_get_catalogue_sum',
#        'rt_ratings_get_catalogue_count', 'rt_ratings_get_catalogue_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_cart_get_catalogue_count', 'rt_cart_get_catalogue_sum',
#        'rt_ratings_get_catalogue_count', 'rt_ratings_get_catalogue_sum'],
#       dtype='object')
# Index(['Unnamed: 0', 'timestamp', 'rt_cart_get_catalogue_count',
#        'rt_cart_get_catalogue_sum', 'rt_ratings_get_catalogue_count',
#        'rt_ratings_get_catalogue_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_cart_get_catalogue_count', 'rt_cart_get_catalogue_sum',
#        'rt_ratings_get_catalogue_count', 'rt_ratings_get_catalogue_sum'],
#       dtype='object')
# ...

# %%
# CSV import for dispatch dataframes from cadvisor
df1_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-cpu-dispatch/dispatch.csv')
df2_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-fileIO-payment/dispatch.csv')
df3_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user/dispatch.csv')
df4_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user-2/dispatch.csv')
df5_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-load-1500/dispatch.csv')
df6_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user/dispatch.csv')
df7_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user-2/dispatch.csv')
df8_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/memory-leak-cart/dispatch.csv')
df9_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user/dispatch.csv')
df10_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user-2/dispatch.csv')
df11_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user/dispatch.csv')
df12_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user-2/dispatch.csv')
df13_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/rt-delay-catalogue/dispatch.csv')
df14_dispatch = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/service-down-payment/dispatch.csv')

# CSV import for dispatch dataframes from response time
# df1_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-cpu-dispatch_rt/dispatch.csv')
# df2_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-fileIO-payment_rt/dispatch.csv')
# df3_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user_rt/dispatch.csv')
# df4_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user-2_rt/dispatch.csv')
# df5_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-load-1500_rt/dispatch.csv')
# df6_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user_rt/dispatch.csv')
# df7_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user-2_rt/dispatch.csv')
# df8_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/memory-leak-cart_rt/dispatch.csv')
# df9_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user_rt/dispatch.csv')
# df10_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user-2_rt/dispatch.csv')
# df11_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user_rt/dispatch.csv')
# df12_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user-2_rt/dispatch.csv')
# df13_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/rt-delay-catalogue_rt/dispatch.csv')
# df14_dispatch_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/service-down-payment_rt/dispatch.csv')

# %%
df1_dispatch['anomaly_type'] = 1
df2_dispatch['anomaly_type'] = 2
df3_dispatch['anomaly_type'] = 3
df4_dispatch['anomaly_type'] = 4
df5_dispatch['anomaly_type'] = 5
df6_dispatch['anomaly_type'] = 6
df7_dispatch['anomaly_type'] = 7
df8_dispatch['anomaly_type'] = 8
df9_dispatch['anomaly_type'] = 9
df10_dispatch['anomaly_type'] = 10
df11_dispatch['anomaly_type'] = 11
df12_dispatch['anomaly_type'] = 12
df13_dispatch['anomaly_type'] = 13
df14_dispatch['anomaly_type'] = 14

# %%
# merge all the df#_dispatch dataframes to create df_dispatch dataframe

df_dispatch = pd.concat([df1_dispatch, df2_dispatch, df3_dispatch, df4_dispatch, df5_dispatch,
                      df6_dispatch, df7_dispatch, df8_dispatch, df9_dispatch, df10_dispatch,
                      df11_dispatch, df12_dispatch, df13_dispatch, df14_dispatch], ignore_index=True)

# %%
# Merged dispatch Dataframe
print(df_dispatch.shape)
# Out:
# (28724, 21)

# %%
print("Dispatch CAdvisor")
print(df1_dispatch.shape)
print(df2_dispatch.shape)
print(df3_dispatch.shape)
print(df4_dispatch.shape)
print(df5_dispatch.shape)
print(df6_dispatch.shape)
print(df7_dispatch.shape)
print(df8_dispatch.shape)
print(df9_dispatch.shape)
print(df10_dispatch.shape)
print(df11_dispatch.shape)
print(df12_dispatch.shape)
print(df13_dispatch.shape)
print(df14_dispatch.shape)
# print("\nDispatch Response Time")
# print(df1_dispatch_rt.shape)
# print(df2_dispatch_rt.shape)
# print(df3_dispatch_rt.shape)
# print(df4_dispatch_rt.shape)
# print(df5_dispatch_rt.shape)
# print(df6_dispatch_rt.shape)
# print(df7_dispatch_rt.shape)
# print(df8_dispatch_rt.shape)
# print(df9_dispatch_rt.shape)
# print(df10_dispatch_rt.shape)
# print(df11_dispatch_rt.shape)
# print(df12_dispatch_rt.shape)
# print(df13_dispatch_rt.shape)
# print(df14_dispatch_rt.shape)
# Out:
# Dispatch CAdvisor
# (1255, 21)
# (1260, 21)
# (1260, 21)
# (4040, 21)
# (3055, 21)
# (1260, 21)
# (2332, 21)
# (1260, 21)
# (1260, 21)
# (2226, 21)
# (1260, 21)
# (5736, 21)
# (1260, 21)
# (1260, 21)

# %%
# CSV import for mongodb dataframes from cadvisor
df1_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-cpu-dispatch/mongodb.csv')
df2_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-fileIO-payment/mongodb.csv')
df3_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user/mongodb.csv')
df4_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user-2/mongodb.csv')
df5_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-load-1500/mongodb.csv')
df6_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user/mongodb.csv')
df7_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user-2/mongodb.csv')
df8_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/memory-leak-cart/mongodb.csv')
df9_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user/mongodb.csv')
df10_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user-2/mongodb.csv')
df11_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user/mongodb.csv')
df12_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user-2/mongodb.csv')
df13_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/rt-delay-catalogue/mongodb.csv')
df14_mongodb = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/service-down-payment/mongodb.csv')

# CSV import for mongodb dataframes from response time
# df1_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-cpu-dispatch_rt/mongodb.csv')
# df2_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-fileIO-payment_rt/mongodb.csv')
# df3_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user_rt/mongodb.csv')
# df4_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user-2_rt/mongodb.csv')
# df5_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-load-1500_rt/mongodb.csv')
# df6_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user_rt/mongodb.csv')
# df7_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user-2_rt/mongodb.csv')
# df8_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/memory-leak-cart_rt/mongodb.csv')
# df9_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user_rt/mongodb.csv')
# df10_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user-2_rt/mongodb.csv')
# df11_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user_rt/mongodb.csv')
# df12_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user-2_rt/mongodb.csv')
# df13_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/rt-delay-catalogue_rt/mongodb.csv')
# df14_mongodb_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/service-down-payment_rt/mongodb.csv')

# %%
df1_mongodb['anomaly_type'] = 1
df2_mongodb['anomaly_type'] = 2
df3_mongodb['anomaly_type'] = 3
df4_mongodb['anomaly_type'] = 4
df5_mongodb['anomaly_type'] = 5
df6_mongodb['anomaly_type'] = 6
df7_mongodb['anomaly_type'] = 7
df8_mongodb['anomaly_type'] = 8
df9_mongodb['anomaly_type'] = 9
df10_mongodb['anomaly_type'] = 10
df11_mongodb['anomaly_type'] = 11
df12_mongodb['anomaly_type'] = 12
df13_mongodb['anomaly_type'] = 13
df14_mongodb['anomaly_type'] = 14

# merge all the df#_mongodb dataframes to create df_mongodb dataframe

df_mongodb = pd.concat([df1_mongodb, df2_mongodb, df3_mongodb, df4_mongodb, df5_mongodb,
                      df6_mongodb, df7_mongodb, df8_mongodb, df9_mongodb, df10_mongodb,
                      df11_mongodb, df12_mongodb, df13_mongodb, df14_mongodb], ignore_index=True)

# Merged mongodb Dataframe
print(df_mongodb.shape)
# Out:
# (27767, 21)

# %%
print("Mongodb CAdvisor")
print(df1_mongodb.shape)
print(df2_mongodb.shape)
print(df3_mongodb.shape)
print(df4_mongodb.shape)
print(df5_mongodb.shape)
print(df6_mongodb.shape)
print(df7_mongodb.shape)
print(df8_mongodb.shape)
print(df9_mongodb.shape)
print(df10_mongodb.shape)
print(df11_mongodb.shape)
print(df12_mongodb.shape)
print(df13_mongodb.shape)
print(df14_mongodb.shape)
# print("\nMongodb Response Time")
# print(df1_mongodb_rt.shape)
# print(df2_mongodb_rt.shape)
# print(df3_mongodb_rt.shape)
# print(df4_mongodb_rt.shape)
# print(df5_mongodb_rt.shape)
# print(df6_mongodb_rt.shape)
# print(df7_mongodb_rt.shape)
# print(df8_mongodb_rt.shape)
# print(df9_mongodb_rt.shape)
# print(df10_mongodb_rt.shape)
# print(df11_mongodb_rt.shape)
# print(df12_mongodb_rt.shape)
# print(df13_mongodb_rt.shape)
# print(df14_mongodb_rt.shape)
# Out:
# Mongodb CAdvisor
# (1255, 21)
# (1260, 21)
# (1260, 21)
# (4308, 21)
# (3054, 21)
# (1260, 21)
# (2355, 21)
# (1260, 21)
# (1260, 21)
# (2248, 21)
# (1260, 21)
# (4467, 21)
# (1260, 21)
# (1260, 21)

# %%
# CSV import for mysql dataframes from cadvisor
df1_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-cpu-dispatch/mysql.csv')
df2_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-fileIO-payment/mysql.csv')
df3_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user/mysql.csv')
df4_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user-2/mysql.csv')
df5_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-load-1500/mysql.csv')
df6_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user/mysql.csv')
df7_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user-2/mysql.csv')
df8_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/memory-leak-cart/mysql.csv')
df9_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user/mysql.csv')
df10_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user-2/mysql.csv')
df11_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user/mysql.csv')
df12_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user-2/mysql.csv')
df13_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/rt-delay-catalogue/mysql.csv')
df14_mysql = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/service-down-payment/mysql.csv')

# CSV import for mysql dataframes from response time
df1_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-cpu-dispatch_rt/mysql.csv')
df2_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-fileIO-payment_rt/mysql.csv')
df3_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user_rt/mysql.csv')
df4_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user-2_rt/mysql.csv')
df5_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-load-1500_rt/mysql.csv')
df6_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user_rt/mysql.csv')
df7_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user-2_rt/mysql.csv')
df8_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/memory-leak-cart_rt/mysql.csv')
df9_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user_rt/mysql.csv')
df10_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user-2_rt/mysql.csv')
df11_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user_rt/mysql.csv')
df12_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user-2_rt/mysql.csv')
df13_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/rt-delay-catalogue_rt/mysql.csv')
df14_mysql_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/service-down-payment_rt/mysql.csv')

# %%
df1_mysql['anomaly_type'] = 1
df2_mysql['anomaly_type'] = 2
df3_mysql['anomaly_type'] = 3
df4_mysql['anomaly_type'] = 4
df5_mysql['anomaly_type'] = 5
df6_mysql['anomaly_type'] = 6
df7_mysql['anomaly_type'] = 7
df8_mysql['anomaly_type'] = 8
df9_mysql['anomaly_type'] = 9
df10_mysql['anomaly_type'] = 10
df11_mysql['anomaly_type'] = 11
df12_mysql['anomaly_type'] = 12
df13_mysql['anomaly_type'] = 13
df14_mysql['anomaly_type'] = 14

# merge all the df#_mysql dataframes to create df_mysql dataframe

df_mysql = pd.concat([df1_mysql, df2_mysql, df3_mysql, df4_mysql, df5_mysql,
                      df6_mysql, df7_mysql, df8_mysql, df9_mysql, df10_mysql,
                      df11_mysql, df12_mysql, df13_mysql, df14_mysql], ignore_index=True)

# Merged mysql Dataframe
print(df_mysql.shape)
# Out:
# (28816, 21)

# %%
print("Mysql CAdvisor")
print(df1_mysql.shape)
print(df2_mysql.shape)
print(df3_mysql.shape)
print(df4_mysql.shape)
print(df5_mysql.shape)
print(df6_mysql.shape)
print(df7_mysql.shape)
print(df8_mysql.shape)
print(df9_mysql.shape)
print(df10_mysql.shape)
print(df11_mysql.shape)
print(df12_mysql.shape)
print(df13_mysql.shape)
print(df14_mysql.shape)
print("\nMysql Response Time")
print(df1_mysql_rt.shape)
print(df2_mysql_rt.shape)
print(df3_mysql_rt.shape)
print(df4_mysql_rt.shape)
print(df5_mysql_rt.shape)
print(df6_mysql_rt.shape)
print(df7_mysql_rt.shape)
print(df8_mysql_rt.shape)
print(df9_mysql_rt.shape)
print(df10_mysql_rt.shape)
print(df11_mysql_rt.shape)
print(df12_mysql_rt.shape)
print(df13_mysql_rt.shape)
print(df14_mysql_rt.shape)
# Out:
# Mysql CAdvisor
# (1255, 21)
# (1260, 21)
# (1260, 21)
# (4041, 21)
# (3052, 21)
# (1260, 21)
# (2377, 21)
# (1260, 21)
# (1260, 21)
# (2271, 21)
# (1260, 21)
# (5740, 21)
# (1260, 21)
# (1260, 21)
#
# Mysql Response Time
# (1255, 3)
# (1260, 3)
# (1259, 3)
# (4300, 4)
# (1079, 3)
# (1260, 3)
# (2411, 4)
# (1260, 3)
# (1260, 3)
# (2294, 4)
# (1260, 3)
# (5746, 4)
# (1260, 3)
# (1260, 3)

# %%
print(df1_mysql_rt.columns)
print(df2_mysql_rt.columns)
print(df3_mysql_rt.columns)
print(df4_mysql_rt.columns)
print(df5_mysql_rt.columns)
print(df6_mysql_rt.columns)
print(df7_mysql_rt.columns)
print(df8_mysql_rt.columns)
print(df9_mysql_rt.columns)
print(df10_mysql_rt.columns)
print(df11_mysql_rt.columns)
print(df12_mysql_rt.columns)
print(df13_mysql_rt.columns)
print(df14_mysql_rt.columns)
# Out:
# Index(['timestamp', 'rt_ratings_put_PDO_count', 'rt_ratings_put_PDO_sum'], dtype='object')
# Index(['timestamp', 'rt_ratings_put_PDO_count', 'rt_ratings_put_PDO_sum'], dtype='object')
# Index(['timestamp', 'rt_ratings_put_PDO_count', 'rt_ratings_put_PDO_sum'], dtype='object')
# Index(['Unnamed: 0', 'timestamp', 'rt_ratings_put_PDO_count',
#        'rt_ratings_put_PDO_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_ratings_put_PDO_count', 'rt_ratings_put_PDO_sum'], dtype='object')
# Index(['timestamp', 'rt_ratings_put_PDO_count', 'rt_ratings_put_PDO_sum'], dtype='object')
# Index(['Unnamed: 0', 'timestamp', 'rt_ratings_put_PDO_count',
#        'rt_ratings_put_PDO_sum'],
#       dtype='object')
# Index(['timestamp', 'rt_ratings_put_PDO_count', 'rt_ratings_put_PDO_sum'], dtype='object')
# Index(['timestamp', 'rt_ratings_put_PDO_count', 'rt_ratings_put_PDO_sum'], dtype='object')
# Index(['Unnamed: 0', 'timestamp', 'rt_ratings_put_PDO_count',
#        'rt_ratings_put_PDO_sum'],
# ...

# %%
# CSV import for payment dataframes from cadvisor
df1_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-cpu-dispatch/payment.csv')
df2_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-fileIO-payment/payment.csv')
df3_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user/payment.csv')
df4_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user-2/payment.csv')
df5_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-load-1500/payment.csv')
df6_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user/payment.csv')
df7_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user-2/payment.csv')
df8_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/memory-leak-cart/payment.csv')
df9_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user/payment.csv')
df10_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user-2/payment.csv')
df11_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user/payment.csv')
df12_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user-2/payment.csv')
df13_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/rt-delay-catalogue/payment.csv')
# df14_payment = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/service-down-payment/payment.csv')

# CSV import for payment dataframes from response time
df1_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-cpu-dispatch_rt/payment.csv')
df2_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-fileIO-payment_rt/payment.csv')
df3_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user_rt/payment.csv')
# df4_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user-2_rt/payment.csv')
df5_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-load-1500_rt/payment.csv')
df6_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user_rt/payment.csv')
df7_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user-2_rt/payment.csv')
df8_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/memory-leak-cart_rt/payment.csv')
df9_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user_rt/payment.csv')
df10_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user-2_rt/payment.csv')
df11_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user_rt/payment.csv')
# df12_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user-2_rt/payment.csv')
df13_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/rt-delay-catalogue_rt/payment.csv')
# df14_payment_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/service-down-payment_rt/payment.csv')

# %%
df1_payment['anomaly_type'] = 1
df2_payment['anomaly_type'] = 2
df3_payment['anomaly_type'] = 3
df4_payment['anomaly_type'] = 4
df5_payment['anomaly_type'] = 5
df6_payment['anomaly_type'] = 6
df7_payment['anomaly_type'] = 7
df8_payment['anomaly_type'] = 8
df9_payment['anomaly_type'] = 9
df10_payment['anomaly_type'] = 10
df11_payment['anomaly_type'] = 11
df12_payment['anomaly_type'] = 12
df13_payment['anomaly_type'] = 13
# df14_payment['anomaly_type'] = 14

# merge all the df#_payment dataframes to create df_payment dataframe

df_payment = pd.concat([df1_payment, df2_payment, df3_payment, df4_payment, df5_payment,
                      df6_payment, df7_payment, df8_payment, df9_payment, df10_payment,
                      df11_payment, df12_payment, df13_payment], ignore_index=True)

# Merged payment Dataframe
print(df_payment.shape)
# Out:
# (26465, 21)

# %%
print("Payment CAdvisor")
print(df1_payment.shape)
print(df2_payment.shape)
print(df3_payment.shape)
print(df4_payment.shape)
print(df5_payment.shape)
print(df6_payment.shape)
print(df7_payment.shape)
print(df8_payment.shape)
print(df9_payment.shape)
print(df10_payment.shape)
print(df11_payment.shape)
print(df12_payment.shape)
print(df13_payment.shape)
# print(df14_payment.shape)
print("\nPayment Response Time")
print(df1_payment_rt.shape)
print(df2_payment_rt.shape)
print(df3_payment_rt.shape)
# print(df4_payment_rt.shape)
print(df5_payment_rt.shape)
print(df6_payment_rt.shape)
print(df7_payment_rt.shape)
print(df8_payment_rt.shape)
print(df9_payment_rt.shape)
print(df10_payment_rt.shape)
print(df11_payment_rt.shape)
# print(df12_payment_rt.shape)
print(df13_payment_rt.shape)
# print(df14_payment_rt.shape)
# Out:
# Payment CAdvisor
# (1255, 21)
# (1260, 21)
# (1260, 21)
# (4304, 21)
# (3052, 21)
# (1260, 21)
# (2337, 21)
# (1260, 21)
# (1260, 21)
# (2231, 21)
# (1260, 21)
# (4466, 21)
# (1260, 21)
#
# Payment Response Time
# (1259, 3)
# (1260, 3)
# (1204, 3)
# (1080, 3)
# (1260, 3)
# (2336, 4)
# (1260, 3)
# (1260, 3)
# (2215, 4)
# (1014, 3)
# (1260, 3)

# %%
# CSV import for rabbitmq dataframes from cadvisor
df1_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-cpu-dispatch/rabbitmq.csv')
df2_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-fileIO-payment/rabbitmq.csv')
df3_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user/rabbitmq.csv')
df4_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user-2/rabbitmq.csv')
df5_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-load-1500/rabbitmq.csv')
df6_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user/rabbitmq.csv')
df7_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user-2/rabbitmq.csv')
df8_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/memory-leak-cart/rabbitmq.csv')
df9_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user/rabbitmq.csv')
df10_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user-2/rabbitmq.csv')
df11_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user/rabbitmq.csv')
df12_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user-2/rabbitmq.csv')
df13_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/rt-delay-catalogue/rabbitmq.csv')
df14_rabbitmq = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/service-down-payment/rabbitmq.csv')

# CSV import for rabbitmq dataframes from response time
df1_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-cpu-dispatch_rt/rabbitmq.csv')
df2_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-fileIO-payment_rt/rabbitmq.csv')
df3_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user_rt/rabbitmq.csv')
df4_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user-2_rt/rabbitmq.csv')
df5_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-load-1500_rt/rabbitmq.csv')
df6_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user_rt/rabbitmq.csv')
df7_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user-2_rt/rabbitmq.csv')
df8_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/memory-leak-cart_rt/rabbitmq.csv')
df9_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user_rt/rabbitmq.csv')
df10_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user-2_rt/rabbitmq.csv')
df11_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user_rt/rabbitmq.csv')
df12_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user-2_rt/rabbitmq.csv')
df13_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/rt-delay-catalogue_rt/rabbitmq.csv')
df14_rabbitmq_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/service-down-payment_rt/rabbitmq.csv')

# %%
df1_rabbitmq['anomaly_type'] = 1
df2_rabbitmq['anomaly_type'] = 2
df3_rabbitmq['anomaly_type'] = 3
df4_rabbitmq['anomaly_type'] = 4
df5_rabbitmq['anomaly_type'] = 5
df6_rabbitmq['anomaly_type'] = 6
df7_rabbitmq['anomaly_type'] = 7
df8_rabbitmq['anomaly_type'] = 8
df9_rabbitmq['anomaly_type'] = 9
df10_rabbitmq['anomaly_type'] = 10
df11_rabbitmq['anomaly_type'] = 11
df12_rabbitmq['anomaly_type'] = 12
df13_rabbitmq['anomaly_type'] = 13
df14_rabbitmq['anomaly_type'] = 14

# merge all the df#_rabbitmq dataframes to create df_rabbitmq dataframe

df_rabbitmq = pd.concat([df1_rabbitmq, df2_rabbitmq, df3_rabbitmq, df4_rabbitmq, df5_rabbitmq,
                      df6_rabbitmq, df7_rabbitmq, df8_rabbitmq, df9_rabbitmq, df10_rabbitmq,
                      df11_rabbitmq, df12_rabbitmq, df13_rabbitmq, df14_rabbitmq], ignore_index=True)

# Merged rabbitmq Dataframe
print(df_rabbitmq.shape)
# Out:
# (27556, 21)

# %%
print("Rabbitmq CAdvisor")
print(df1_rabbitmq.shape)
print(df2_rabbitmq.shape)
print(df3_rabbitmq.shape)
print(df4_rabbitmq.shape)
print(df5_rabbitmq.shape)
print(df6_rabbitmq.shape)
print(df7_rabbitmq.shape)
print(df8_rabbitmq.shape)
print(df9_rabbitmq.shape)
print(df10_rabbitmq.shape)
print(df11_rabbitmq.shape)
print(df12_rabbitmq.shape)
print(df13_rabbitmq.shape)
print(df14_rabbitmq.shape)
print("\nRabbitmq Response Time")
print(df1_rabbitmq_rt.shape)
print(df2_rabbitmq_rt.shape)
print(df3_rabbitmq_rt.shape)
print(df4_rabbitmq_rt.shape)
print(df5_rabbitmq_rt.shape)
print(df6_rabbitmq_rt.shape)
print(df7_rabbitmq_rt.shape)
print(df8_rabbitmq_rt.shape)
print(df9_rabbitmq_rt.shape)
print(df10_rabbitmq_rt.shape)
print(df11_rabbitmq_rt.shape)
print(df12_rabbitmq_rt.shape)
print(df13_rabbitmq_rt.shape)
print(df14_rabbitmq_rt.shape)
# Out:
# Rabbitmq CAdvisor
# (1255, 21)
# (1260, 21)
# (1260, 21)
# (4041, 21)
# (3054, 21)
# (1260, 21)
# (2382, 21)
# (1260, 21)
# (1260, 21)
# (2277, 21)
# (1260, 21)
# (4467, 21)
# (1260, 21)
# (1260, 21)
#
# Rabbitmq Response Time
# (1260, 3)
# (1260, 3)
# (1260, 3)
# (4302, 4)
# (1080, 3)
# (1260, 3)
# (2415, 4)
# (1260, 3)
# (1260, 3)
# (2298, 4)
# (1260, 3)
# (5748, 4)
# (1260, 3)
# (1260, 3)

# %%
# CSV import for ratings dataframes from cadvisor
df1_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-cpu-dispatch/ratings.csv')
df2_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-fileIO-payment/ratings.csv')
df3_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user/ratings.csv')
df4_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user-2/ratings.csv')
df5_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-load-1500/ratings.csv')
df6_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user/ratings.csv')
df7_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user-2/ratings.csv')
df8_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/memory-leak-cart/ratings.csv')
df9_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user/ratings.csv')
df10_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user-2/ratings.csv')
df11_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user/ratings.csv')
df12_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user-2/ratings.csv')
df13_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/rt-delay-catalogue/ratings.csv')
df14_ratings = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/service-down-payment/ratings.csv')

# CSV import for ratings dataframes from response time
df1_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-cpu-dispatch_rt/ratings.csv')
df2_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-fileIO-payment_rt/ratings.csv')
df3_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user_rt/ratings.csv')
df4_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user-2_rt/ratings.csv')
df5_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-load-1500_rt/ratings.csv')
df6_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user_rt/ratings.csv')
df7_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user-2_rt/ratings.csv')
df8_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/memory-leak-cart_rt/ratings.csv')
df9_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user_rt/ratings.csv')
df10_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user-2_rt/ratings.csv')
df11_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user_rt/ratings.csv')
df12_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user-2_rt/ratings.csv')
df13_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/rt-delay-catalogue_rt/ratings.csv')
df14_ratings_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/service-down-payment_rt/ratings.csv')

# %%
df1_ratings['anomaly_type'] = 1
df2_ratings['anomaly_type'] = 2
df3_ratings['anomaly_type'] = 3
df4_ratings['anomaly_type'] = 4
df5_ratings['anomaly_type'] = 5
df6_ratings['anomaly_type'] = 6
df7_ratings['anomaly_type'] = 7
df8_ratings['anomaly_type'] = 8
df9_ratings['anomaly_type'] = 9
df10_ratings['anomaly_type'] = 10
df11_ratings['anomaly_type'] = 11
df12_ratings['anomaly_type'] = 12
df13_ratings['anomaly_type'] = 13
df14_ratings['anomaly_type'] = 14

# merge all the df#_ratings dataframes to create df_ratings dataframe

df_ratings = pd.concat([df1_ratings, df2_ratings, df3_ratings, df4_ratings, df5_ratings,
                      df6_ratings, df7_ratings, df8_ratings, df9_ratings, df10_ratings,
                      df11_ratings, df12_ratings, df13_ratings, df14_ratings], ignore_index=True)

# Merged ratings Dataframe
print(df_ratings.shape)
# Out:
# (28743, 21)

# %%
print("Ratings CAdvisor")
print(df1_ratings.shape)
print(df2_ratings.shape)
print(df3_ratings.shape)
print(df4_ratings.shape)
print(df5_ratings.shape)
print(df6_ratings.shape)
print(df7_ratings.shape)
print(df8_ratings.shape)
print(df9_ratings.shape)
print(df10_ratings.shape)
print(df11_ratings.shape)
print(df12_ratings.shape)
print(df13_ratings.shape)
print(df14_ratings.shape)
print("\nRatings Response Time")
print(df1_ratings_rt.shape)
print(df2_ratings_rt.shape)
print(df3_ratings_rt.shape)
print(df4_ratings_rt.shape)
print(df5_ratings_rt.shape)
print(df6_ratings_rt.shape)
print(df7_ratings_rt.shape)
print(df8_ratings_rt.shape)
print(df9_ratings_rt.shape)
print(df10_ratings_rt.shape)
print(df11_ratings_rt.shape)
print(df12_ratings_rt.shape)
print(df13_ratings_rt.shape)
print(df14_ratings_rt.shape)
# Out:
# Ratings CAdvisor
# (1255, 21)
# (1260, 21)
# (1260, 21)
# (4039, 21)
# (3051, 21)
# (1260, 21)
# (2343, 21)
# (1260, 21)
# (1260, 21)
# (2237, 21)
# (1260, 21)
# (5738, 21)
# (1260, 21)
# (1260, 21)
#
# Ratings Response Time
# (1255, 3)
# (1260, 3)
# (1259, 3)
# (4300, 4)
# (1079, 3)
# (1260, 3)
# (2333, 4)
# (1260, 3)
# (1260, 3)
# (2212, 4)
# (1260, 3)
# (5746, 4)
# (1260, 3)
# (1260, 3)

# %%
# CSV import for redis dataframes from cadvisor
df1_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-cpu-dispatch/redis.csv')
df2_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-fileIO-payment/redis.csv')
df3_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user/redis.csv')
df4_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user-2/redis.csv')
df5_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-load-1500/redis.csv')
df6_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user/redis.csv')
df7_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user-2/redis.csv')
df8_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/memory-leak-cart/redis.csv')
df9_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user/redis.csv')
df10_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user-2/redis.csv')
df11_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user/redis.csv')
df12_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user-2/redis.csv')
df13_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/rt-delay-catalogue/redis.csv')
df14_redis = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/service-down-payment/redis.csv')

# CSV import for redis dataframes from response time
df1_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-cpu-dispatch_rt/redis.csv')
df2_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-fileIO-payment_rt/redis.csv')
df3_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user_rt/redis.csv')
df4_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user-2_rt/redis.csv')
df5_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-load-1500_rt/redis.csv')
df6_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user_rt/redis.csv')
df7_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user-2_rt/redis.csv')
df8_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/memory-leak-cart_rt/redis.csv')
df9_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user_rt/redis.csv')
df10_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user-2_rt/redis.csv')
df11_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user_rt/redis.csv')
df12_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user-2_rt/redis.csv')
df13_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/rt-delay-catalogue_rt/redis.csv')
df14_redis_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/service-down-payment_rt/redis.csv')

# %%
df1_redis['anomaly_type'] = 1
df2_redis['anomaly_type'] = 2
df3_redis['anomaly_type'] = 3
df4_redis['anomaly_type'] = 4
df5_redis['anomaly_type'] = 5
df6_redis['anomaly_type'] = 6
df7_redis['anomaly_type'] = 7
df8_redis['anomaly_type'] = 8
df9_redis['anomaly_type'] = 9
df10_redis['anomaly_type'] = 10
df11_redis['anomaly_type'] = 11
df12_redis['anomaly_type'] = 12
df13_redis['anomaly_type'] = 13
df14_redis['anomaly_type'] = 14

# merge all the df#_redis dataframes to create df_redis dataframe

df_redis = pd.concat([df1_redis, df2_redis, df3_redis, df4_redis, df5_redis,
                      df6_redis, df7_redis, df8_redis, df9_redis, df10_redis,
                      df11_redis, df12_redis, df13_redis, df14_redis], ignore_index=True)

# Merged redis Dataframe
print(df_redis.shape)
# Out:
# (27533, 21)

# %%
print("Redis CAdvisor")
print(df1_redis.shape)
print(df2_redis.shape)
print(df3_redis.shape)
print(df4_redis.shape)
print(df5_redis.shape)
print(df6_redis.shape)
print(df7_redis.shape)
print(df8_redis.shape)
print(df9_redis.shape)
print(df10_redis.shape)
print(df11_redis.shape)
print(df12_redis.shape)
print(df13_redis.shape)
print(df14_redis.shape)
print("\nRedis Response Time")
print(df1_redis_rt.shape)
print(df2_redis_rt.shape)
print(df3_redis_rt.shape)
print(df4_redis_rt.shape)
print(df5_redis_rt.shape)
print(df6_redis_rt.shape)
print(df7_redis_rt.shape)
print(df8_redis_rt.shape)
print(df9_redis_rt.shape)
print(df10_redis_rt.shape)
print(df11_redis_rt.shape)
print(df12_redis_rt.shape)
print(df13_redis_rt.shape)
print(df14_redis_rt.shape)
# Out:
# Redis CAdvisor
# (1255, 21)
# (1260, 21)
# (1260, 21)
# (4042, 21)
# (3053, 21)
# (1260, 21)
# (2371, 21)
# (1260, 21)
# (1260, 21)
# (2265, 21)
# (1260, 21)
# (4467, 21)
# (1260, 21)
# (1260, 21)
#
# Redis Response Time
# (1260, 9)
# (1260, 9)
# (1260, 9)
# (4303, 10)
# (1080, 9)
# (1260, 7)
# (2406, 10)
# (1260, 9)
# (1260, 9)
# (2291, 10)
# (1260, 9)
# (5736, 10)
# (1260, 9)
# (1260, 9)

# %%
# CSV import for shipping dataframes from cadvisor
df1_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-cpu-dispatch/shipping.csv')
df2_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-fileIO-payment/shipping.csv')
df3_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user/shipping.csv')
df4_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user-2/shipping.csv')
# df5_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-load-1500/shipping.csv')
df6_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user/shipping.csv')
df7_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user-2/shipping.csv')
df8_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/memory-leak-cart/shipping.csv')
df9_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user/shipping.csv')
df10_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user-2/shipping.csv')
df11_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user/shipping.csv')
df12_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user-2/shipping.csv')
df13_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/rt-delay-catalogue/shipping.csv')
df14_shipping = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/service-down-payment/shipping.csv')

# CSV import for shipping dataframes from response time
df1_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-cpu-dispatch_rt/shipping.csv')
df2_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-fileIO-payment_rt/shipping.csv')
df3_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user_rt/shipping.csv')
df4_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user-2_rt/shipping.csv')
# df5_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-load-1500_rt/shipping.csv')
df6_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user_rt/shipping.csv')
# df7_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user-2_rt/shipping.csv')
df8_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/memory-leak-cart_rt/shipping.csv')
df9_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user_rt/shipping.csv')
df10_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user-2_rt/shipping.csv')
df11_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user_rt/shipping.csv')
df12_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user-2_rt/shipping.csv')
df13_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/rt-delay-catalogue_rt/shipping.csv')
df14_shipping_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/service-down-payment_rt/shipping.csv')

# %%
df1_shipping['anomaly_type'] = 1
df2_shipping['anomaly_type'] = 2
df3_shipping['anomaly_type'] = 3
df4_shipping['anomaly_type'] = 4
# df5_shipping['anomaly_type'] = 5
df6_shipping['anomaly_type'] = 6
df7_shipping['anomaly_type'] = 7
df8_shipping['anomaly_type'] = 8
df9_shipping['anomaly_type'] = 9
df10_shipping['anomaly_type'] = 10
df11_shipping['anomaly_type'] = 11
df12_shipping['anomaly_type'] = 12
df13_shipping['anomaly_type'] = 13
df14_shipping['anomaly_type'] = 14

# merge all the df#_shipping dataframes to create df_shipping dataframe

df_shipping = pd.concat([df1_shipping, df2_shipping, df3_shipping, df4_shipping,
                      df6_shipping, df7_shipping, df8_shipping, df9_shipping, df10_shipping,
                      df11_shipping, df12_shipping, df13_shipping, df14_shipping], ignore_index=True)

# Merged shipping Dataframe
print(df_shipping.shape)
# Out:
# (24696, 21)

# %%
print("Shipping CAdvisor")
print(df1_shipping.shape)
print(df2_shipping.shape)
print(df3_shipping.shape)
print(df4_shipping.shape)
# print(df5_shipping.shape)
print(df6_shipping.shape)
print(df7_shipping.shape)
print(df8_shipping.shape)
print(df9_shipping.shape)
print(df10_shipping.shape)
print(df11_shipping.shape)
print(df12_shipping.shape)
print(df13_shipping.shape)
print(df14_shipping.shape)
print("\nShipping Response Time")
print(df1_shipping_rt.shape)
print(df2_shipping_rt.shape)
print(df3_shipping_rt.shape)
print(df4_shipping_rt.shape)
# print(df5_shipping_rt.shape)
print(df6_shipping_rt.shape)
# print(df7_shipping_rt.shape)
print(df8_shipping_rt.shape)
print(df9_shipping_rt.shape)
print(df10_shipping_rt.shape)
print(df11_shipping_rt.shape)
print(df12_shipping_rt.shape)
print(df13_shipping_rt.shape)
print(df14_shipping_rt.shape)
# Out:
# Shipping CAdvisor
# (1255, 21)
# (1260, 21)
# (1260, 21)
# (4303, 21)
# (1260, 21)
# (2349, 21)
# (1260, 21)
# (1260, 21)
# (2243, 21)
# (1260, 21)
# (4466, 21)
# (1260, 21)
# (1260, 21)
#
# Shipping Response Time
# (1260, 7)
# (1260, 7)
# (1260, 7)
# (3919, 8)
# (1260, 7)
# (1239, 7)
# (1260, 7)
# (2229, 8)
# (1260, 7)
# (5348, 8)
# (1260, 7)
# (1260, 7)

# %%
# CSV import for web dataframes from cadvisor
df1_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-cpu-dispatch/web.csv')
df2_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-fileIO-payment/web.csv')
df3_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user/web.csv')
df4_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-latency-user-2/web.csv')
df5_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/high-load-1500/web.csv')
df6_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user/web.csv')
df7_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/low-bandwidth-user-2/web.csv')
df8_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/memory-leak-cart/web.csv')
df9_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user/web.csv')
df10_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/out-of-order-packets-user-2/web.csv')
df11_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user/web.csv')
df12_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/packetloss-user-2/web.csv')
df13_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/rt-delay-catalogue/web.csv')
df14_web = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/cAdvisor/service-down-payment/web.csv')

# CSV import for web dataframes from response time
# df1_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-cpu-dispatch_rt/web.csv')
# df2_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-fileIO-payment_rt/web.csv')
# df3_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user_rt/web.csv')
# df4_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-latency-user-2_rt/web.csv')
# df5_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/high-load-1500_rt/web.csv')
# df6_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user_rt/web.csv')
# df7_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/low-bandwidth-user-2_rt/web.csv')
# df8_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/memory-leak-cart_rt/web.csv')
# df9_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user_rt/web.csv')
# df10_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/out-of-order-packets-user-2_rt/web.csv')
# df11_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user_rt/web.csv')
# df12_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/packetloss-user-2_rt/web.csv')
# df13_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/rt-delay-catalogue_rt/web.csv')
# df14_web_rt = pd.read_csv('/content/drive/MyDrive/rs-anomic/Initial Data/anomaly_data/response_times/service-down-payment_rt/web.csv')

# %%
df1_web['anomaly_type'] = 1
df2_web['anomaly_type'] = 2
df3_web['anomaly_type'] = 3
df4_web['anomaly_type'] = 4
df5_web['anomaly_type'] = 5
df6_web['anomaly_type'] = 6
df7_web['anomaly_type'] = 7
df8_web['anomaly_type'] = 8
df9_web['anomaly_type'] = 9
df10_web['anomaly_type'] = 10
df11_web['anomaly_type'] = 11
df12_web['anomaly_type'] = 12
df13_web['anomaly_type'] = 13
df14_web['anomaly_type'] = 14

# merge all the df#_web dataframes to create df_web dataframe

df_web = pd.concat([df1_web, df2_web, df3_web, df4_web, df5_web,
                      df6_web, df7_web, df8_web, df9_web, df10_web,
                      df11_web, df12_web, df13_web, df14_web], ignore_index=True)

# Merged web Dataframe
print(df_web.shape)
# Out:
# (29035, 21)

# %%
print("Web CAdvisor")
print(df1_web.shape)
print(df2_web.shape)
print(df3_web.shape)
print(df4_web.shape)
print(df5_web.shape)
print(df6_web.shape)
print(df7_web.shape)
print(df8_web.shape)
print(df9_web.shape)
print(df10_web.shape)
print(df11_web.shape)
print(df12_web.shape)
print(df13_web.shape)
print(df14_web.shape)
# print("\nWeb Response Time")
# print(df1_web_rt.shape)
# print(df2_web_rt.shape)
# print(df3_web_rt.shape)
# print(df4_web_rt.shape)
# print(df5_web_rt.shape)
# print(df6_web_rt.shape)
# print(df7_web_rt.shape)
# print(df8_web_rt.shape)
# print(df9_web_rt.shape)
# print(df10_web_rt.shape)
# print(df11_web_rt.shape)
# print(df12_web_rt.shape)
# print(df13_web_rt.shape)
# print(df14_web_rt.shape)
# Out:
# Web CAdvisor
# (1255, 21)
# (1260, 21)
# (1260, 21)
# (4301, 21)
# (3054, 21)
# (1258, 21)
# (2359, 21)
# (1260, 21)
# (1260, 21)
# (2253, 21)
# (1260, 21)
# (5735, 21)
# (1260, 21)
# (1260, 21)

# %%
# Merged Dataframes list

Merged_Dataframes = [df_cart, df_catalogue, df_dispatch, df_mongodb, df_mysql, df_payment, df_rabbitmq, df_ratings, df_redis, df_shipping, df_user, df_web]

# %%
for df in Merged_Dataframes:
  print(df.shape)
# Out:
# (27782, 21)
# (29103, 21)
# (28724, 21)
# (27767, 21)
# (28816, 21)
# (26465, 21)
# (27556, 21)
# (28743, 21)
# (27533, 21)
# (24696, 21)
# (28710, 21)
# (29035, 21)

# %%
Merged_df = pd.concat(Merged_Dataframes, ignore_index=True)

# %%
Merged_df.shape
# Out:
# (334930, 21)

# %%
# prompt: print the columns

print(Merged_df.columns)
# Out:
# Index(['timestamp', 'container_fs_usage_bytes', 'container_memory_rss',
#        'container_memory_usage_bytes', 'container_memory_working_set_bytes',
#        'container_cpu_system_seconds_total',
#        'container_cpu_usage_seconds_total', 'container_cpu_user_seconds_total',
#        'container_network_receive_bytes_total',
#        'container_network_receive_errors_total',
#        'container_network_receive_packets_dropped_total',
#        'container_network_receive_packets_total',
#        'container_network_transmit_bytes_total',
#        'container_network_transmit_errors_total',
#        'container_network_transmit_packets_dropped_total',
#        'container_network_transmit_packets_total',
#        'container_fs_io_time_seconds_total', 'container_memory_failures_total',
#        'container_memory_failcnt', 'container_fs_write_seconds_total',
#        'anomaly_type'],
#       dtype='object')

# %%
# prompt: save the above as a csv

Merged_df.to_csv('/content/drive/MyDrive/rs-anomic/Modified New/merged_anomaly_data.csv', index=False)
